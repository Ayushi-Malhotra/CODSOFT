# %% [markdown]
# <a href="https://colab.research.google.com/github/Ayushi-Malhotra/CODSOFT/blob/main/seaborn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

flowers_df= sns.load_dataset("iris")
flowers_df
sns.set_style("darkgrid")

# %%
flowers_df.species.unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
plt.plot(flowers_df.sepal_length,flowers_df.sepal_width);

# %%
plt.scatter(flowers_df.sepal_length,flowers_df.sepal_width);

# %%
sns.scatterplot(x='sepal_length', y='sepal_width', hue='species', data=flowers_df);

# %%
flowers_df=sns.load_dataset("iris")

# %%
flowers_df.sepal_width
# Out:
# 0      3.5
# 1      3.0
# 2      3.2
# 3      3.1
# 4      3.6
#       ...
# 145    3.0
# 146    2.5
# 147    3.0
# 148    3.4
# 149    3.0
# Name: sepal_width, Length: 150, dtype: float64

# %%
plt.title("Distribution of sepal width")
plt.hist(flowers_df.sepal_width,bins=5)
# Out:
# (array([11., 46., 68., 21.,  4.]),
#  array([2.  , 2.48, 2.96, 3.44, 3.92, 4.4 ]),
#  <BarContainer object of 5 artists>)

# %%
flowers_df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
import numpy as np
np.arange(2,5,0.25)
# Out:
# array([2.  , 2.25, 2.5 , 2.75, 3.  , 3.25, 3.5 , 3.75, 4.  , 4.25, 4.5 ,
#        4.75])

# %%
###multiplt histograms

# %%
setosa_df=flowers_df[flowers_df.species=='setosa']
versicolor_df= flowers_df[flowers_df.species =='versicolor']
virginica_df= flowers_df[flowers_df.species=='virginica']

# %%
plt.hist(setosa_df.sepal_width,alpha=0.4,bins=np.arange(2,5,0.25));
plt.hist(versicolor_df.sepal_width,alpha=0.4,bins=np.arange(2,5,0.25));

plt.legend(['setosa','versicolor'])

# %%
##stacking multiple hist on top of one another

# %%
plt.figure(figsize=(8,5))
plt.title('distribution of sepal width')
plt.hist([setosa_df.sepal_width, versicolor_df.sepal_width,virginica_df.sepal_width],bins=np.arange(2,5,0.25), stacked=True);
plt.legend(['setosa','versicolor','virginica']);

# %% [markdown]
# ***bar charts***

# %%
years= range(2000, 2006)
apples=[0.35,0.6,0.9,0.8,0.65,0.8]
oranges=[0.4,0.8,0.9,0.7,0.6,0.8]

# %%
plt.plot(years,apples)

# %%
plt.bar(years,oranges);

# %%
plt.bar(years,oranges);
plt.plot(years,oranges,'o--r')
plt.title('yield of oranges')
# Out:
# Text(0.5, 1.0, 'yield of oranges')

# %%
plt.bar(years,apples)
plt.bar(years,oranges,bottom=apples);

# %% [markdown]
# ***bar plots with avgs***

# %%
tips_df=sns.load_dataset("tips");
tips_df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
bills_avg=tips_df.groupby('day')[['total_bill']].mean()
bills_avg
# Out:
# <ipython-input-67-0692f32d8214>:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   bills_avg=tips_df.groupby('day')[['total_bill']].mean()
#       total_bill
# day
# Thur   17.682742
# Fri    17.151579
# Sat    20.441379
# Sun    21.410000

# %%
plt.bar(bills_avg.index,bills_avg.total_bill)
# Out:
# <BarContainer object of 4 artists>

# %%
sns.barplot(x='day', y='total_bill', data=tips_df);

# %%
sns.barplot(x='day', y='total_bill', hue='sex', data=tips_df);

# %% [markdown]
# heatmap

# %%
sns.load_dataset("flights")
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
plt.plot(sns.load_dataset("flights").passengers)

# %%
flights_df= sns.load_dataset("flights").pivot("month","year","passengers");
flights_df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-80-57ed234b2340> in <cell line: 1>()
# ----> 1 flights_df= sns.load_dataset("flights").pivot("month","year","passengers");
#       2 flights_df
#
# TypeError: DataFrame.pivot() takes 1 positional argument but 4 were given

# %%
flights_df = sns.load_dataset("flights").pivot(index="month", columns="year", values="passengers")
flights_df
# Out:
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472
# Jun     135   149   178   218   243   264   315   374   422   435   472   535
# Jul     148   170   199   230   264   302   364   413   465   491   548   622
# Aug     148   170   199   242   272   293   347   405   467   505   559   606
# Sep     136   158   184   209   237   259   312   355   404   404   463   508
# Oct     119   133   162   191   211   229   274   306   347   359   407   461
# Nov     104   114   146   172   180   203   237   271   305   310   362   390
# ...

# %%
plt.title("No. of passengers (1000s)")
sns.heatmap(flights_df,fmt="d",annot=True,cmap='Blues');
